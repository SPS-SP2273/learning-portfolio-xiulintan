# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# ## Exercise 1 (Tidying a collaboration)

# %% [markdown]
# Task 1

# %%
old_file_name = 'oct-08_singapore.txt'
month={
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}
file_1=old_file_name.split("-")
word_month=file_1[0]
month_1=month[word_month]
text=file_1[1].split("_")

final=month_1+'-'+text[0]+'-'+text[1]
print(final)
# Out:
# 10-08-singapore.txt

# %% [markdown]
# Task 2

# %%
def rename_my_file(old_file_name):
    month={'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'}

    file_1=old_file_name.split("-")
    word_month=file_1[0]
    month_1=month[word_month]
    text=file_1[1].split("_")

    final=month_1+'-'+text[0]+'-'+text[1]
    return final

print(rename_my_file('oct-08_singapore.txt'))
# Out:
# 10-08-singapore.txt

# %% [markdown]
# Task 3

# %%
for old_file_name in ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']:
    new_file_name=rename_my_file(old_file_name)
    print(f'{old_file_name} ----> {new_file_name}') # anything in the () treated as str, f looks for {variable}
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %% [markdown]
# Task 4

# %%
import glob
import os

# %%
glob.glob('os-collaboration-exercise-data/os-collaboration-exercise-data/*.txt')
# Out:
# ['os-collaboration-exercise-data/os-collaboration-exercise-data\\apr-01_melbourne.txt',
#  'os-collaboration-exercise-data/os-collaboration-exercise-data\\apr-01_shanghai.txt',
#  'os-collaboration-exercise-data/os-collaboration-exercise-data\\apr-01_singapore.txt',
#  'os-collaboration-exercise-data/os-collaboration-exercise-data\\apr-02_cairo.txt',
#  'os-collaboration-exercise-data/os-collaboration-exercise-data\\apr-02_jakarta.txt',
#  'os-collaboration-exercise-data/os-collaboration-exercise-data\\apr-02_karachi.txt',
#  'os-collaboration-exercise-data/os-collaboration-exercise-data\\apr-02_shanghai.txt',
#  'os-collaboration-exercise-data/os-collaboration-exercise-data\\apr-03_manila.txt',
#  'os-collaboration-exercise-data/os-collaboration-exercise-data\\apr-03_osaka.txt',
#  'os-collaboration-exercise-data/os-collaboration-exercise-data\\apr-03_singapore.txt',
#  'os-collaboration-exercise-data/os-collaboration-exercise-data\\apr-03_tokyo.txt',
# ...

# %%
def rename_my_file_1(old_file_name):
    month={'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'}

    file_1=old_file_name.split("\\")
    file_2=file_1[1].split("-")
    word_month=file_2[0]
    month_1=month[word_month]
    text=file_2[1].split("_")

    final=os.path.join(file_1[0], month_1 + '-' + text[0] + '-' + text[1])
    return final

# %%
for file in glob.glob("os-collaboration-exercise-data/os-collaboration-exercise-data/*.txt"):
    new_name=rename_my_file_1(file)
    os.rename(file,new_name)

# %% [markdown]
# Task 5

# %%
for city in ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']:
    os.mkdir(city)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[65], line 3
#       1 for city in ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
#       2  'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']:
# ----> 3     os.mkdir(city)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Cairo'

# %% [markdown]
# Task 6

# %%
import shutil

# %%
cairo_list=glob.glob('os-collaboration-exercise-data/os-collaboration-exercise-data/*cairo*')

# %%
for files in cairo_list:
    shutil.copy(files,'Cairo')

# %% [markdown]
# Task 7

# %%
for city in ['Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']:
    city_lowercase=city.lower()
    city_list=glob.glob(f'os-collaboration-exercise-data/os-collaboration-exercise-data/*{city_lowercase}*')
    for city_place in city_list:
        shutil.move(city_place, city)
