# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# ## Exercise 1 (Tidying a collaboration)

# %% [markdown]
# Task 1

# %%
old_file_name = 'oct-08_singapore.txt'
month={
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}
file_1=old_file_name.split("-")
word_month=file_1[0]
month_1=month[word_month]
text=file_1[1].split("_")

final=month_1+'-'+text[0]+'-'+text[1]
print(final)
# Out:
# 10-08-singapore.txt

# %% [markdown]
# Task 2

# %%
def rename_my_file(old_file_name):
    month={'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'}

    file_1=old_file_name.split("-")
    word_month=file_1[0]
    month_1=month[word_month]
    text=file_1[1].split("_")

    final=month_1+'-'+text[0]+'-'+text[1]
    return final

print(rename_my_file('oct-08_singapore.txt'))
# Out:
# 10-08-singapore.txt

# %% [markdown]
# Task 3

# %%
for old_file_name in ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']:
    new_file_name=rename_my_file(old_file_name)
    print(f'{old_file_name} ----> {new_file_name}') # anything in the () treated as str, f looks for {variable}
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %% [markdown]
# Task 4

# %%
import glob
import os

# %%
glob.glob('*/*.txt')
# Out:
# ['os-collaboration-exercise-data\\apr-01_melbourne.txt',
#  'os-collaboration-exercise-data\\apr-01_shanghai.txt',
#  'os-collaboration-exercise-data\\apr-01_singapore.txt',
#  'os-collaboration-exercise-data\\apr-02_cairo.txt',
#  'os-collaboration-exercise-data\\apr-02_jakarta.txt',
#  'os-collaboration-exercise-data\\apr-02_karachi.txt',
#  'os-collaboration-exercise-data\\apr-02_shanghai.txt',
#  'os-collaboration-exercise-data\\apr-03_manila.txt',
#  'os-collaboration-exercise-data\\apr-03_osaka.txt',
#  'os-collaboration-exercise-data\\apr-03_singapore.txt',
#  'os-collaboration-exercise-data\\apr-03_tokyo.txt',
#  'os-collaboration-exercise-data\\apr-04_manila.txt',
#  'os-collaboration-exercise-data\\apr-04_melbourne.txt',
#  'os-collaboration-exercise-data\\apr-04_shanghai.txt',
#  'os-collaboration-exercise-data\\apr-04_singapore.txt',
#  'os-collaboration-exercise-data\\apr-05_karachi.txt',
#  'os-collaboration-exercise-data\\apr-05_melbourne.txt',
# ...

# %%
for file in glob.glob('*/*.txt'):
    file_name_split=file.split('\\')
    file_name=file_name_split[1]
    new_name=os.path.join(file_name_split[0],rename_my_file(file_name))
    os.rename(file, new_name)

# %% [markdown]
# Task 5

# %%
for city in ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']:
    os.mkdir(city)

# %% [markdown]
# Task 6

# %%
import shutil

# %%
cairo_list=glob.glob('os-collaboration-exercise-data/*cairo*')
print(cairo_list)
# Out:
# ['os-collaboration-exercise-data\\01-02-cairo.txt', 'os-collaboration-exercise-data\\01-03-cairo.txt', 'os-collaboration-exercise-data\\01-04-cairo.txt', 'os-collaboration-exercise-data\\01-05-cairo.txt', 'os-collaboration-exercise-data\\01-07-cairo.txt', 'os-collaboration-exercise-data\\01-08-cairo.txt', 'os-collaboration-exercise-data\\01-09-cairo.txt', 'os-collaboration-exercise-data\\01-11-cairo.txt', 'os-collaboration-exercise-data\\01-12-cairo.txt', 'os-collaboration-exercise-data\\01-13-cairo.txt', 'os-collaboration-exercise-data\\01-15-cairo.txt', 'os-collaboration-exercise-data\\01-16-cairo.txt', 'os-collaboration-exercise-data\\01-19-cairo.txt', 'os-collaboration-exercise-data\\01-20-cairo.txt', 'os-collaboration-exercise-data\\01-21-cairo.txt', 'os-collaboration-exercise-data\\01-23-cairo.txt', 'os-collaboration-exercise-data\\01-27-cairo.txt', 'os-collaboration-exercise-data\\01-30-cairo.txt', 'os-collaboration-exercise-data\\02-10-cairo.txt', 'os-collaboration-exercise-d
# ...

# %%
for files in cairo_list:
    shutil.copy(files,'Cairo')

# %% [markdown]
# Task 7

# %%
for city in ['Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']:
    city_lowercase=city.lower()
    city_list=glob.glob(f'os-collaboration-exercise-data/*{city_lowercase}*')
    for city_place in city_list:
        shutil.move(city_place, city)
